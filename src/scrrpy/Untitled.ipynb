# %%
import drr
# %matplotlib inline

# %%
d = drr.DRR(0.01,1)

# %%
d1,d2 = d.drr(1,1,1).T
# Out:
#  99% (99 of 100) |######################################################################################################################################################################################################  | Elapsed Time: 0:00:51 ETA: 0:00:00

# %%
clf()
plot(d.j, (d2 + d1))
loglog(d.j, (d.j)**(4)*16)
loglog(d.j, (1-d.j)/50*16)
# Out:
# /home/benbaror/.local/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
clf()
plot(d.j, (d2 + d1))
loglog(d.j, (d.j)**(4)*16)
loglog(d.j, (1-d.j)/50*16)
# Out:
# /home/benbaror/.local/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
clf()
plot(d.j, (d2 + d1))
plot(d.j, (1-d.j)/50*16)
ylim(0,0.2)
# Out:
# (0, 0.2)
# /home/benbaror/.local/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
